# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# %%
#t15A = pd.read_html('https://www.iplt20.com/auction/2015')
t15B = pd.read_html('https://en.wikipedia.org/wiki/List_of_2015_Indian_Premier_League_personnel_changes')

# %%
t18B = pd.read_html('https://en.wikipedia.org/wiki/List_of_2018_Indian_Premier_League_personnel_changes')

# %%
t12B = pd.read_html('https://en.wikipedia.org/wiki/List_of_2012_Indian_Premier_League_personnel_changes')

# %%
t09B = pd.read_html('https://en.wikipedia.org/wiki/List_of_2009_Indian_Premier_League_personnel_changes')

# %%
a = t15B[3].drop(['IPL Matches','Nat','Capped / uncapped','IPL 2014 team','IPL team(s)'],axis=1)

# %%
b = t18B[5].drop(['IPL Matches','Set','Set No','Country','Capped / Uncapped /Associate','IPL Team(s)','IPL 2017 Team'],axis=1)

# %%
a
# Out:
#                      Name  Base Price in ₹ (in lakhs)[5]  \
# 0          Michael Hussey                            150
# 1            Irfan Pathan                            150
# 2            Rahul Sharma                             30
# 3             Kyle Abbott                             30
# 4              Andrew Tye                             20
# 5          Pratyush Singh                             10
# 6            Ankush Bains                             10
# 7         Eklavya Dwivedi                             10
# 8            Yuvraj Singh                            200
# 9          Angelo Mathews                            150
# 10            Zaheer Khan                            100
# 11            Amit Mishra                             10
# 12           Shreyas Iyer                             10
# 13        Gurinder Sandhu                             30
# 14         Jaydev Unadkat                             50
# ...

# %%
r1=a.rename(columns={'Name':'Player','IPL 2015 team':'Team 2015','Base Price in ₹ (in lakhs)[5]':'Base.P 2015','Auctioned price in ₹ (in lakhs)':'Auction.P 2015'})

# %%
r2=b1.rename(columns={'Name':'Player','IPL 2018 Team':'Team 2018','Reserve Price (in ₹ Lacs)':'Base.P 2018','Auctioned Price (in ₹ Lacs)':'Auction.P 2018'})

# %%
b.to_csv('b1.csv',index=False)
b1 = pd.read_csv('b11.csv')

# %%
r3=c.rename(columns={'Team':'Team 2012','Base price':'Base.P 2012','Winning bid':'Auction.P 2012'})

# %%
c = t12B[9].drop('Nat',axis=1)

# %%
c
# Out:
#                   Player                         Team Base price Winning bid
# 0       Brendon McCullum        Kolkata Knight Riders   $400,000    $900,000
# 1        Ravindra Jadeja          Chennai Super Kings   $100,000  $2,000,000
# 2   Muttiah Muralitharan  Royal Challengers Bangalore   $200,000    $220,000
# 3     Mahela Jayawardene             Delhi Daredevils   $300,000  $1,400,000
# 4       Herschelle Gibbs               Mumbai Indians    $50,000     $50,000
# 5             Brad Hodge             Rajasthan Royals   $200,000    $475,000
# 6          Parthiv Patel              Deccan Chargers   $200,000    $650,000
# 7       Dinesh Chandimal             Rajasthan Royals    $50,000     $50,000
# 8          Andre Russell             Delhi Daredevils    $50,000    $450,000
# 9       Mitchell Johnson               Mumbai Indians   $300,000    $300,000
# 10           R. P. Singh               Mumbai Indians   $200,000    $600,000
# ...

# %%
r2.tail()
# Out:
#                   Player Playing Role  Base.P 2018              Team 2018  \
# 164          Chris Gayle      Batsman          200        Kings XI Punjab
# 165  Dushmantha Chameera       Bowler           50       Rajasthan Royals
# 166       M. D. Nidheesh       Bowler           20         Mumbai Indians
# 167          Manzoor Dar  All-Rounder           20        Kings XI Punjab
# 168        Javon Searles  All-Rounder           30  Kolkata Knight Riders
#
#      Auction.P 2018
# 164             200
# 165              50
# 166              20
# 167              20
# 168              30

# %% [markdown]
# #

# %%
d = t09B[7].drop('Nat',axis=1)

# %%
r4=d.rename(columns={'Team':'Team 2009','Base price':'Base.P 2009','Winning bid':'Auction.P 2009'})

# %%
d
# Out:
#                Player                         Team Winning bid  Base price
# 0          Shaun Tait             Rajasthan Royals    $375,000    $250,000
# 1           JP Duminy               Mumbai Indians    $950,000    $300,000
# 2     Andrew Flintoff          Chennai Super Kings  $1,550,000    $950,000
# 3     Kevin Pietersen  Royal Challengers Bangalore  $1,550,000  $1,350,000
# 4       Fidel Edwards              Deccan Chargers    $150,000    $150,000
# 5          Owais Shah             Delhi Daredevils    $275,000    $150,000
# 6    Paul Collingwood             Delhi Daredevils    $275,000    $250,000
# 7     Tyron Henderson             Rajasthan Royals    $650,000    $100,000
# 8         Ravi Bopara              Kings XI Punjab    $450,000    $150,000
# 9     Thilan Thushara          Chennai Super Kings    $140,000    $100,000
# 10        Jesse Ryder  Royal Challengers Bangalore    $160,000    $100,000
# ...

# %%
r5 = pd.merge(r1,r2,on='Player',how='outer')

# %%
r6 = pd.merge(r3,r4,on='Player',how='outer')

# %%
r7 = pd.merge(r5,r6,on='Player',how='outer')

# %%
r7.to_csv('abhinav.csv',index=False)

# %%
r7.tail()
# Out:
#                 Player  Base.P 2015 Team 2015  Auction.P 2015 Playing Role  \
# 251       Dwayne Smith          NaN       NaN             NaN          NaN
# 252      Jerome Taylor          NaN       NaN             NaN          NaN
# 253  Mohammad Ashraful          NaN       NaN             NaN          NaN
# 254   Mashrafe Mortaza          NaN       NaN             NaN          NaN
# 255      George Bailey          NaN       NaN             NaN          NaN
#
#      Base.P 2018 Team 2018  Auction.P 2018 Team 2012 Base.P 2012  \
# 251          NaN       NaN             NaN       NaN         NaN
# 252          NaN       NaN             NaN       NaN         NaN
# 253          NaN       NaN             NaN       NaN         NaN
# 254          NaN       NaN             NaN       NaN         NaN
# 255          NaN       NaN             NaN       NaN         NaN
#
#     Auction.P 2012              Team 2009 Auction.P 2009 Base.P 2009
# ...

# %%
r2.tail()
# Out:
#                            Player Playing Role  Base.P 2018  \
# 164          Chris Gayle[REC-1&2]      Batsman          200
# 165  Dushmantha Chameera[REC-1&2]       Bowler           50
# 166    M. D. Nidheesh[DI-REC-1&2]       Bowler           20
# 167         Manzoor Dar[DI-REC-2]  All-Rounder           20
# 168       Javon Searles[DI-REC-2]  All-Rounder           30
#
#                  Team 2018  Auction.P 2018
# 164        Kings XI Punjab             200
# 165       Rajasthan Royals              50
# 166         Mumbai Indians              20
# 167        Kings XI Punjab              20
# 168  Kolkata Knight Riders              30

# %%
r3
# Out:
#                   Player                    Team 2012 Base.P 2012  \
# 0       Brendon McCullum        Kolkata Knight Riders    $400,000
# 1        Ravindra Jadeja          Chennai Super Kings    $100,000
# 2   Muttiah Muralitharan  Royal Challengers Bangalore    $200,000
# 3     Mahela Jayawardene             Delhi Daredevils    $300,000
# 4       Herschelle Gibbs               Mumbai Indians     $50,000
# 5             Brad Hodge             Rajasthan Royals    $200,000
# 6          Parthiv Patel              Deccan Chargers    $200,000
# 7       Dinesh Chandimal             Rajasthan Royals     $50,000
# 8          Andre Russell             Delhi Daredevils     $50,000
# 9       Mitchell Johnson               Mumbai Indians    $300,000
# 10           R. P. Singh               Mumbai Indians    $200,000
# 11           Vinay Kumar  Royal Challengers Bangalore    $100,000
# 12             Sreesanth             Rajasthan Royals    $400,000
# ...

# %%
    r4
# Out:
#                Player                    Team 2009 Auction.P 2009 Base.P 2009
# 0          Shaun Tait             Rajasthan Royals       $375,000    $250,000
# 1           JP Duminy               Mumbai Indians       $950,000    $300,000
# 2     Andrew Flintoff          Chennai Super Kings     $1,550,000    $950,000
# 3     Kevin Pietersen  Royal Challengers Bangalore     $1,550,000  $1,350,000
# 4       Fidel Edwards              Deccan Chargers       $150,000    $150,000
# 5          Owais Shah             Delhi Daredevils       $275,000    $150,000
# 6    Paul Collingwood             Delhi Daredevils       $275,000    $250,000
# 7     Tyron Henderson             Rajasthan Royals       $650,000    $100,000
# 8         Ravi Bopara              Kings XI Punjab       $450,000    $150,000
# 9     Thilan Thushara          Chennai Super Kings       $140,000    $100,000
# 10        Jesse Ryder  Royal Challengers Bangalore       $160,000    $100,000
# ...

# %%
import requests

import pandas as pd 
from pandas import DataFrame,Series

# %%
web_url = requests.get('https://en.wikipedia.org/wiki/List_of_2009_Indian_Premier_League_personnel_changes').text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(web_url,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of 2009 Indian Premier League personnel changes - Wikipedia
#   </title>
#   <script>
# ...

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
My_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Nat
# </th>
# <th>Player
# </th>
# <th>Team
# </th>
# <th>Winning bid
# </th>
# <th>Base price
# </th></tr>
# <tr>
# <td><span data-sort-value="Australia !"><span class="flagicon"><a href="/wiki/Australia" title="Australia"><img alt="Australia" class="thumbborder" data-file-height="640" data-file-width="1280" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/23px-Flag_of_Australia_%28converted%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/35px-Flag_of_Australia_%28converted%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/46px-Flag_of_Australia_%28converted%29.svg.png 2x" width="23"/></a></span></span></td>
# <td><a href="/wiki/Shaun_Tait" title="Shaun Tait">Shaun Tait</a>
# </td>
# ...

# %%
nations = My_table.findAll('img')
nations
# Out:
# [<img alt="Australia" class="thumbborder" data-file-height="640" data-file-width="1280" decoding="async" height="12" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/23px-Flag_of_Australia_%28converted%29.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/35px-Flag_of_Australia_%28converted%29.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/88/Flag_of_Australia_%28converted%29.svg/46px-Flag_of_Australia_%28converted%29.svg.png 2x" width="23"/>,
# ...

# %%
Nationality =[]
for nation in nations:
    Nationality.append(nation.get('alt'))
    
print(Nationality)
# Out:
# ['Australia', 'South Africa', 'England', 'England', 'West Indies Cricket Board', 'England', 'England', 'South Africa', 'England', 'Sri Lanka', 'New Zealand', 'New Zealand', 'West Indies Cricket Board', 'West Indies Cricket Board', 'Bangladesh', 'Bangladesh', 'Australia']

# %%
Nationality.sort()
print(Nationality)
# Out:
# ['Australia', 'Australia', 'Bangladesh', 'Bangladesh', 'England', 'England', 'England', 'England', 'England', 'New Zealand', 'New Zealand', 'South Africa', 'South Africa', 'Sri Lanka', 'West Indies Cricket Board', 'West Indies Cricket Board', 'West Indies Cricket Board']

# %%
Nationality=pd.DataFrame(Nationality)
N1=Nationality.rename(columns={0:'Nationality'})

# %%
_2009 =t09B[7]

# %%
fi=pd.concat([_2009,N1],axis=1)
fi.drop('Nat',axis=1)
# Out:
#                Player                         Team Winning bid  Base price  \
# 0          Shaun Tait             Rajasthan Royals    $375,000    $250,000
# 1           JP Duminy               Mumbai Indians    $950,000    $300,000
# 2     Andrew Flintoff          Chennai Super Kings  $1,550,000    $950,000
# 3     Kevin Pietersen  Royal Challengers Bangalore  $1,550,000  $1,350,000
# 4       Fidel Edwards              Deccan Chargers    $150,000    $150,000
# 5          Owais Shah             Delhi Daredevils    $275,000    $150,000
# 6    Paul Collingwood             Delhi Daredevils    $275,000    $250,000
# 7     Tyron Henderson             Rajasthan Royals    $650,000    $100,000
# 8         Ravi Bopara              Kings XI Punjab    $450,000    $150,000
# 9     Thilan Thushara          Chennai Super Kings    $140,000    $100,000
# 10        Jesse Ryder  Royal Challengers Bangalore    $160,000    $100,000
# ...

# %%
pd.merge(r7,fi,how='outer')
# Out:
#                 Player  Base.P 2015              Team 2015  Auction.P 2015  \
# 0       Michael Hussey        150.0    Chennai Super Kings           150.0
# 1         Irfan Pathan        150.0    Chennai Super Kings           150.0
# 2         Rahul Sharma         30.0    Chennai Super Kings            30.0
# 3          Kyle Abbott         30.0    Chennai Super Kings            30.0
# 4           Andrew Tye         20.0    Chennai Super Kings            20.0
# 5       Pratyush Singh         10.0    Chennai Super Kings            10.0
# 6         Ankush Bains         10.0    Chennai Super Kings            10.0
# 7      Eklavya Dwivedi         10.0    Chennai Super Kings            10.0
# 8         Yuvraj Singh        200.0       Delhi Daredevils          1600.0
# 9       Angelo Mathews        150.0       Delhi Daredevils           750.0
# 10         Zaheer Khan        100.0       Delhi Daredevils           400.0
# ...

# %%
web_url = '1.txt'
# Out:
#   File "<ipython-input-55-4efaba508f4d>", line 1
#     web_url = '
#                ^
# SyntaxError: EOL while scanning string literal

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(web_url,'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
#    1.txt
#   </p>
#  </body>
# </html>
# C:\Users\abhinav.jha\AppData\Local\Continuum\anaconda3\lib\site-packages\bs4\__init__.py:272: UserWarning: "b'1.txt'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
My_table

# %%
html="""

<tbody><tr>
<th>Nat
</th>
<th>Player
</th>
<th>Team
</th>
<th>Base price
</th>
<th>Winning bid
</th></tr>
<tr>
<td><span data-sort-value="New Zealand&#160;!"><span class="flagicon"><a href="/wiki/New_Zealand" title="New Zealand"><img alt="New Zealand" src="//upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_New_Zealand.svg/23px-Flag_of_New_Zealand.svg.png" decoding="async" width="23" height="12" class="thumbborder" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_New_Zealand.svg/35px-Flag_of_New_Zealand.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/3/3e/Flag_of_New_Zealand.svg/46px-Flag_of_New_Zealand.svg.png 2x" data-file-width="1200" data-file-height="600" /></a></span></span></td>
<td><span data-sort-value="McCullum, Brendon"><span class="vcard"><span class="fn"><a href="/wiki/Brendon_McCullum" title="Brendon McCullum">Brendon McCullum</a></span></span></span>
</td>
<td><a href="/wiki/Kolkata_Knight_Riders" title="Kolkata Knight Riders">Kolkata Knight Riders</a>
</td>
<td>$400,000
</td>
<td>$900,000
</td></tr>
<tr>
"""

# %%
a = soup.find_all(html)

# %%
a
# Out:
# []

# %%
nations = My_table.findAll('img')
nations
# Out:
# [<img alt="India" class="thumbborder" data-file-height="900" data-file-width="1350" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/>,
#  <img alt="India" class="thumbborder" data-file-height="900" data-file-width="1350" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/23px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/35px-Flag_of_India.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/45px-Flag_of_India.svg.png 2x" width="23"/>,
# ...

# %%
Nationality =[]
for nation in nations:
    Nationality.append(nation.get('alt'))
    
print(Nationality)
# Out:
# ['India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'South Africa', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'India', 'Jamaica', 'India', 'India', 'India', 'India', 'India']
