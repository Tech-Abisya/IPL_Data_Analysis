# %%
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('datasets/1819.csv')

# %%
data.head()
# Out:
#    match_id  inning    batting_team         bowling_team  over  ball  \
# 0      7894       1  Mumbai Indians  Chennai Super Kings     1     1
# 1      7894       1  Mumbai Indians  Chennai Super Kings     1     2
# 2      7894       1  Mumbai Indians  Chennai Super Kings     1     3
# 3      7894       1  Mumbai Indians  Chennai Super Kings     1     4
# 4      7894       1  Mumbai Indians  Chennai Super Kings     1     5
#
#      batsman non_striker     bowler  is_super_over  ...  noball_runs  \
# 0  RG Sharma     E Lewis  DL Chahar              0  ...            0
# 1  RG Sharma     E Lewis  DL Chahar              0  ...            0
# 2  RG Sharma     E Lewis  DL Chahar              0  ...            0
# 3  RG Sharma     E Lewis  DL Chahar              0  ...            0
# 4  RG Sharma     E Lewis  DL Chahar              0  ...            0
#
#    penalty_runs  batsman_runs  extra_runs  total_runs  player_dismissed  \
# ...

# %%
a = data.groupby('batsman')['batsman_runs'].agg('sum').reset_index().sort_values(by='batsman_runs',ascending=False)
a.to_csv('BatsmansRuns1819.csv',index=False)

# %%
a = a.iloc[:10]

# %%
a
# Out:
#             batsman  batsman_runs
# 80         KL Rahul          1288
# 135         RR Pant          1228
# 139        S Dhawan          1071
# 169         V Kohli          1011
# 158       SR Watson           986
# 13         AS Yadav           962
# 5    AB de Villiers           942
# 29          CA Lynn           924
# 103        MS Dhoni           917
# 14        AT Rayudu           910

# %%
df = pd.DataFrame(a,index=['batsman'],columns=pd.Index(['batsman_runs']))

# %%
a.plot.bar(x='batsman')

# %%
a['batsman']
# Out:
# 486           V Kohli
# 428          SK Raina
# 367         RG Sharma
# 112         DA Warner
# 392          S Dhawan
# 92           CH Gayle
# 290          MS Dhoni
# 384        RV Uthappa
# 26     AB de Villiers
# 147         G Gambhir
# Name: batsman, dtype: object

# %%
c = data.groupby('bowler')['player_dismissed'].agg('count').reset_index().sort_values(by='player_dismissed',ascending=False)
c.to_csv('bowler.csv',index=False)

# %%
aa = data.groupby(['match_id','batsman'])['batsman_runs'].agg('sum').reset_index().sort_values(by='batsman_runs',ascending=False)
#aa.to_csv("highest_runs.csv",index=False)
aa
# Out:
#       match_id         batsman  batsman_runs
# 634       7935         RR Pant           130
# 902       7953       SR Watson           121
# 1051     11147      J Bairstow           115
# 238       7909        CH Gayle           111
# 263       7910       SR Watson           108
# 1475     11331       AM Rahane           108
# 1018     11144       SV Samson           106
# 1303     11319        CH Gayle           105
# 1251     11315        KL Rahul           104
# 1050     11147       DA Warner           101
# 1518     11334      KD Karthik           101
# 603       7933        KL Rahul           101
# 1041     11146          P Shaw           100
# 1414     11326         V Kohli           100
# 682       7939       AT Rayudu           100
# 742       7943        KL Rahul            99
# 1493     11332       SR Watson            98
# 1285     11317        S Dhawan            98
# 218       7907       RG Sharma            97
# 410       7919         SS Iyer            97
# ...

# %%
aa.plot.bar()

# %%
c = c.iloc[:10]

# %%
abc = aa.groupby('batsman')['batsman_runs'].agg(lambda x: (x>50).sum()).reset_index().sort_values(by='batsman_runs', ascending=False).reset_index(drop=True)
abc.to_csv("fifty1819.csv",index=False)
abc
# Out:
#              batsman  batsman_runs
# 0           KL Rahul            13
# 1     AB de Villiers            11
# 2            RR Pant             9
# 3           S Dhawan             9
# 4          DA Warner             9
# 5           CH Gayle             8
# 6         JC Buttler             8
# 7      KS Williamson             8
# 8            V Kohli             8
# 9          SR Watson             7
# 10        AD Russell             7
# 11          SK Raina             7
# 12           CA Lynn             7
# 13          MS Dhoni             6
# 14           SS Iyer             6
# 15          AS Yadav             6
# 16         MK Pandey             6
# 17         AT Rayudu             5
# 18         SV Samson             5
# 19         Q de Kock             5
# 20           E Lewis             4
# 21            N Rana             4
# 22        KD Karthik             4
# 23            P Shaw             4
# 24            S Gill             4
# 25         RG Sharma             4
# ...

# %%
_100 = aa.groupby('batsman')['batsman_runs'].agg(lambda x: (x>=100).sum()).reset_index().sort_values(by='batsman_runs', ascending=False).reset_index(drop=True)
#abc.to_csv("fifty.csv",index=False)
_100.to_csv("hundred1819.csv",index=False)
_100
# Out:
#              batsman  batsman_runs
# 0           CH Gayle             2
# 1          SR Watson             2
# 2           KL Rahul             2
# 3            RR Pant             1
# 4          AM Rahane             1
# 5             P Shaw             1
# 6         KD Karthik             1
# 7          SV Samson             1
# 8         J Bairstow             1
# 9          DA Warner             1
# 10         AT Rayudu             1
# 11           V Kohli             1
# 12         PP Chawla             0
# 13           R Salam             0
# 14         R Tewatia             0
# 15         P Krishna             0
# 16            P Negi             0
# 17        P R Barman             0
# 18             P Raj             0
# 19           R Singh             0
# 20           R Parag             0
# 21        PJ Sangwan             0
# 22            R Bhui             0
# 23          R Ashwin             0
# 24          PA Patel             0
# 25           NV Ojha             0
# ...

# %%
_30 = aa.groupby('batsman')['batsman_runs'].agg(lambda x: (x>=30).sum()).reset_index().sort_values(by='batsman_runs', ascending=False).reset_index(drop=True)
#abc.to_csv("fifty.csv",index=False)
#_100.to_csv("hundred.csv",index=False)
_30.to_csv("thirty1819.csv",index=False)
_30
# Out:
#                batsman  batsman_runs
# 0             KL Rahul            17
# 1              RR Pant            16
# 2             S Dhawan            15
# 3        KS Williamson            15
# 4             AS Yadav            15
# 5              SS Iyer            14
# 6              V Kohli            14
# 7              CA Lynn            14
# 8             MS Dhoni            13
# 9             SK Raina            13
# 10          AD Russell            13
# 11           SR Watson            12
# 12           AT Rayudu            12
# 13           AM Rahane            12
# 14      AB de Villiers            12
# 15          JC Buttler            11
# 16          KD Karthik            11
# 17          RV Uthappa            11
# 18           Q de Kock            11
# 19           SV Samson            11
# 20            CH Gayle            11
# 21           DA Warner            10
# 22            PA Patel            10
# 23           HH Pandya             9
# ...

# %%
asd = data.groupby(['match_id','bowler'])['player_dismissed'].agg('count').reset_index().sort_values(by='player_dismissed',ascending=False)
asd.head()
# Out:
#       match_id      bowler  player_dismissed
# 1073       608  AD Russell                 6
# 1172       616     A Zampa                 6
# 1171       616     A Nehra                 5
# 218         19     B Kumar                 5
# 145         13      AJ Tye                 5

# %%
bol = data.groupby(['batsman'])['batsman'].count()
bol=pd.DataFrame(bol)
booll= bol.rename(columns={'batsman':'no of balls'})
booll.reset_index()
booll.head()
# Out:
#              no of balls
# batsman
# A Dananjaya            5
# A Hales              119
# A Joseph              13
# A Mishra              28
# A Turner              11

# %%
bol1 = data.groupby(['batsman'])['batsman_runs'].sum()
bol1=pd.DataFrame(bol1)
bol1= bol1.rename(columns={'batsman':'no of runs'})
bol1.reset_index()
# Out:
#                batsman  batsman_runs
# 0          A Dananjaya             4
# 1              A Hales           152
# 2             A Joseph            15
# 3             A Mishra            28
# 4             A Turner             4
# 5       AB de Villiers           942
# 6              AD Nath            71
# 7           AD Russell           871
# 8             AJ Finch           140
# 9               AJ Tye            41
# 10           AM Rahane           793
# 11            AR Patel           200
# 12          AS Rajpoot            12
# 13            AS Yadav           962
# 14           AT Rayudu           910
# 15        Ankit Sharma            77
# 16       Anureet Singh             4
# 17          Avesh Khan             4
# 18             B Kumar            32
# 19          B Laughlin             1
# 20          B Stanlake             5
# 21           BA Stokes           331
# 22         BB McCullum           138
# 23             BB Sran             7
# ...

# %%
bol2=pd.merge(booll,bol1,on='batsman')
bol2.head()
bol22=bol2.reset_index()

bol22['strike']=bol22['batsman_runs']/bol22['no of balls']
bol22['strike']=bol22['strike']*100
bol22.to_csv('strike1819.csv',index=False)
bol22.head()
# Out:
#        batsman  no of balls  batsman_runs      strike
# 0  A Dananjaya            5             4   80.000000
# 1      A Hales          119           152  127.731092
# 2     A Joseph           13            15  115.384615
# 3     A Mishra           28            28  100.000000
# 4     A Turner           11             4   36.363636

# %%
bol.to_csv('')
# Out:
# batsman
# A Ashish Reddy           196
# A Chandila                 7
# A Chopra                  75
# A Choudhary               20
# A Flintoff                57
# A Kumble                  49
# A Mishra                 382
# A Mithun                  26
# A Mukund                  23
# A Nehra                   63
# A Singh                   10
# A Symonds                781
# A Uniyal                   7
# A Zampa                    8
# AA Bilakhia               88
# AA Chavan                 11
# AA Jhunjhunwala          218
# AA Noffke                 12
# AB Agarkar               160
# AB Barath                 43
# AB Dinda                  50
# AB McDonald              103
# AB de Villiers          2402
# AC Blizzard               91
# AC Gilchrist            1555
# AC Thomas                 19
# AC Voges                 143
# AD Mascarenhas            79
# AD Mathews               599
# AD Nath                   28
#                         ...
# ...

# %%
abc
# Out:
#               batsman  batsman_runs
# 0           DA Warner            39
# 1             V Kohli            35
# 2           G Gambhir            35
# 3           RG Sharma            33
# 4            SK Raina            32
# 5            S Dhawan            28
# 6            CH Gayle            27
# 7      AB de Villiers            26
# 8           AM Rahane            26
# 9          RV Uthappa            22
# 10           SE Marsh            21
# 11           V Sehwag            18
# 12          JH Kallis            17
# 13           MS Dhoni            17
# 14           DR Smith            17
# 15          SR Watson            16
# 16         MEK Hussey            16
# 17        BB McCullum            15
# 18            M Vijay            15
# 19          YK Pathan            15
# 20          AT Rayudu            14
# 21         KD Karthik            14
# 22          JP Duminy            14
# 23       SR Tendulkar            14
# 24       AC Gilchrist            13
# ...

# %%
aa
# Out:
#       match_id           batsman  batsman_runs
# 6200       411          CH Gayle           175
# 900         60       BB McCullum           158
# 8426       562    AB de Villiers           133
# 9257       620    AB de Villiers           129
# 5585       372          CH Gayle           128
# 3135       206           M Vijay           127
# 529         36         DA Warner           126
# 7752       516          V Sehwag           122
# 3686       243       PC Valthaty           120
# 4223       279          V Sehwag           119
# 8358       557          CH Gayle           117
# 1017        68         A Symonds           117
# 919         61        MEK Hussey           116
# 1467        97          SE Marsh           115
# 7767       517           WP Saha           115
# 2599       171         MK Pandey           114
# 1458        96     ST Jayasuriya           114
# 9346       626           V Kohli           113
# 5712       380           M Vijay           113
# ...

# %%
c
# Out:
#               bowler  player_dismissed
# 294       SL Malinga               170
# 5           A Mishra               142
# 88          DJ Bravo               137
# 117  Harbhajan Singh               136
# 229        PP Chawla               133
# 244    R Vinay Kumar               125
# 7            A Nehra               121
# 355           Z Khan               119
# 50           B Kumar               117
# 234         R Ashwin               110

# %%
c.plot.bar(x='bowler',color='k')

# %%
d = data.groupby('bowling_team')['total_runs'].agg('sum').reset_index().sort_values(by='total_runs',ascending=False)

# %%
d
# Out:
#                    bowling_team  total_runs
# 7                Mumbai Indians       23835
# 12  Royal Challengers Bangalore       23622
# 4               Kings XI Punjab       23270
# 2              Delhi Daredevils       22343
# 6         Kolkata Knight Riders       22035
# 0           Chennai Super Kings       19790
# 9              Rajasthan Royals       17854
# 1               Deccan Chargers       11618
# 13          Sunrisers Hyderabad       11465
# 8                 Pune Warriors        6857
# 3                 Gujarat Lions        5090
# 10       Rising Pune Supergiant        2436
# 11      Rising Pune Supergiants        2113
# 5          Kochi Tuskers Kerala        1986

# %%
d.plot.bar(x='bowling_team')

# %%
e = data.groupby('bowling_team')['extra_runs'].agg('sum').reset_index().sort_values(by='extra_runs',ascending=False)

# %%
e
# Out:
#                    bowling_team  extra_runs
# 7                Mumbai Indians        1397
# 12  Royal Challengers Bangalore        1309
# 4               Kings XI Punjab        1230
# 6         Kolkata Knight Riders        1204
# 2              Delhi Daredevils        1187
# 9              Rajasthan Royals        1058
# 0           Chennai Super Kings        1002
# 1               Deccan Chargers         659
# 13          Sunrisers Hyderabad         487
# 8                 Pune Warriors         335
# 3                 Gujarat Lions         188
# 10       Rising Pune Supergiant         111
# 5          Kochi Tuskers Kerala         110
# 11      Rising Pune Supergiants         108

# %%
e.plot.bar(x='bowling_team')

# %%
f = pd.merge(d,e,on='bowling_team',how='outer')

# %%
f
# Out:
#                    bowling_team  total_runs  extra_runs
# 0                Mumbai Indians       23835        1397
# 1   Royal Challengers Bangalore       23622        1309
# 2               Kings XI Punjab       23270        1230
# 3              Delhi Daredevils       22343        1187
# 4         Kolkata Knight Riders       22035        1204
# 5           Chennai Super Kings       19790        1002
# 6              Rajasthan Royals       17854        1058
# 7               Deccan Chargers       11618         659
# 8           Sunrisers Hyderabad       11465         487
# 9                 Pune Warriors        6857         335
# 10                Gujarat Lions        5090         188
# 11       Rising Pune Supergiant        2436         111
# 12      Rising Pune Supergiants        2113         108
# 13         Kochi Tuskers Kerala        1986         110

# %%
f.plot.barh(x='bowling_team')

# %%
g = data.groupby(['fielder'])[('fielder')].agg('count').sort_values(ascending=False)

# %%
h

# %%
g=g.iloc[:10]

# %%
g
# Out:
# fielder
# MS Dhoni          159
# KD Karthik        152
# RV Uthappa        125
# SK Raina          115
# AB de Villiers    114
# PA Patel           97
# RG Sharma          92
# V Kohli            90
# KA Pollard         85
# NV Ojha            82
# Name: fielder, dtype: int64

# %%
g.plot.bar(x='fielder')

# %%
h = data.groupby(['player_dismissed'])[('player_dismissed')].agg('count').sort_values(ascending=False)

# %%
h=h.iloc[:10]

# %%
h
# Out:
# player_dismissed
# SK Raina        134
# G Gambhir       131
# RG Sharma       129
# RV Uthappa      128
# V Kohli         118
# KD Karthik      117
# S Dhawan        109
# PA Patel        107
# Yuvraj Singh    101
# DA Warner       100
# Name: player_dismissed, dtype: int64

# %%
h.plot.bar(x='player_dismissed')

# %%
i = data.groupby(['bowler'])[('wide_runs')].agg('sum').sort_values(ascending=False)

# %%
i
# Out:
# bowler
# JP Faulkner          11
# JJ Bumrah             8
# CH Morris             7
# Kamran Khan           7
# R Vinay Kumar         7
# DW Steyn              6
# R Rampaul             6
# SP Narine             6
# UT Yadav              6
# J Theron              5
# M Muralitharan        4
# BAW Mendis            4
# MG Johnson            4
# Harbhajan Singh       0
# HH Pandya             0
# Gurkeerat Singh       0
# Gagandeep Singh       0
# HV Patel              0
# Harmeet Singh (2)     0
# Harmeet Singh         0
# I Malhotra            0
# I Sharma              0
# IC Pandey             0
# IK Pathan             0
# Imran Tahir           0
# Iqbal Abdulla         0
# J Botha               0
# GS Sandhu             0
# Z Khan                0
# GR Napier             0
#                      ..
# RR Bhatkal            0
# RR Bose               0
# RR Powar              0
# RR Raje               0
# RS Bopara             0
# RS Gavaskar           0
# RV Gomez              0
# ...

# %%
j = data.groupby(['bowler'])[('total_runs')].agg('sum').sort_values(ascending=False)

# %%
j.head()
# Out:
# bowler
# P Kumar       144
# SL Malinga    143
# DW Steyn      105
# DJ Bravo       93
# SR Watson      90
# Name: wide_runs, dtype: int64

# %%
h = data.groupby(['bowler'])[('extra_runs')].agg('sum').sort_values(ascending=False)

# %%
h.head()
# Out:
# bowler
# S Sreesanth    27
# I Sharma       21
# A Mishra       20
# SL Malinga     18
# JA Morkel      18
# Name: noball_runs, dtype: int64

# %%
h = data.groupby(['bowler'])[('noball_runs')].agg('sum').sort_values(ascending=False)
#h.to_csv('noBallRuns1819.csv',index=False)

# %%
h.head()
# Out:
# bowler
# AS Rajpoot    7
# JJ Bumrah     6
# N Saini       5
# K Paul        5
# DL Chahar     5
# Name: noball_runs, dtype: int64

# %%
i =data.groupby(['bowler'])[('is_super_over')].agg('sum').sort_values(ascending=False)
i.head()
# Out:
# bowler
# JP Faulkner      11
# JJ Bumrah         8
# CH Morris         7
# Kamran Khan       7
# R Vinay Kumar     7
# Name: is_super_over, dtype: int64

# %%
j = data.groupby(['bowler'])[('wide_runs')].agg('sum').sort_values(ascending=False)
#j.to_csv('wideRuns1819.csv',index=False)

# %%
j.head()
# Out:
# bowler
# Mohammed Siraj    34
# DJ Bravo          31
# DL Chahar         27
# YS Chahal         26
# HH Pandya         26
# Name: wide_runs, dtype: int64

# %%
k = data.groupby(['bowler'])[('over')].agg('count').sort_values(ascending=False)

# %%
k
# Out:
# bowler
# Harbhajan Singh     2989
# A Mishra            2703
# SL Malinga          2694
# P Kumar             2637
# PP Chawla           2594
# R Ashwin            2359
# Z Khan              2276
# R Vinay Kumar       2161
# DW Steyn            2159
# IK Pathan           2113
# DJ Bravo            2110
# B Kumar             2054
# UT Yadav            2033
# A Nehra             1974
# RA Jadeja           1962
# SR Watson           1961
# SP Narine           1956
# PP Ojha             1945
# RP Singh            1874
# JA Morkel           1807
# JH Kallis           1799
# I Sharma            1713
# M Morkel            1699
# R Bhatia            1661
# AB Dinda            1589
# M Muralitharan      1581
# L Balaji            1574
# MM Sharma           1566
# SK Trivedi          1557
# DS Kulkarni         1485
#                     ...
# S Rana                16
# Abdur Razzak          14
# AA Kazi               13
# LRPL Taylor           13
# S Vidyut              13
# ...

# %%
z = data.groupby('batsman').agg('count').reset_index().sort_values(by='batsman_runs',ascending=False)

# %%
z
# Out:
#               batsman  match_id  inning  batting_team  bowling_team  over  \
# 431           V Kohli      3494    3494          3494          3494  3494
# 137         G Gambhir      3433    3433          3433          3433  3433
# 374          SK Raina      3369    3369          3369          3369  3369
# 323         RG Sharma      3274    3274          3274          3274  3274
# 347          S Dhawan      3005    3005          3005          3005  3005
# 340        RV Uthappa      2960    2960          2960          2960  2960
# 103         DA Warner      2902    2902          2902          2902  2902
# 259          MS Dhoni      2680    2680          2680          2680  2680
# 38          AM Rahane      2602    2602          2602          2602  2602
# 85           CH Gayle      2532    2532          2532          2532  2532
# 22     AB de Villiers      2402    2402          2402          2402  2402
# 195        KD Karthik      2360    2360          2360          2360  2360
# ...

# %%
bowl=data.groupby(['match_id','bowler','over'])['total_runs'].sum()
bowl_eco=pd.DataFrame(bowl)

# %%
batsman_per_over = bowl_eco.reset_index()
batsman_per_over
batsman_per_over.to_csv("batsman_per_over.csv",index=False)

# %%
a = batsman_per_over.groupby(['batsman','over'])['total_runs'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4aa398d4c9c2> in <module>
# ----> 1 a = batsman_per_over.groupby(['batsman','over'])['total_runs'].sum()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# ...

# %%
a
# Out:
# batsman         over
# A Ashish Reddy  5         0
#                 6         6
#                 12        1
#                 13        9
#                 14       22
#                 15       29
#                 16       22
#                 17       32
#                 18       42
#                 19       66
#                 20       59
# A Chandila      17        1
#                 18        1
#                 19        1
#                 20        1
# A Chopra        1         2
#                 2         8
#                 3         3
#                 4         1
#                 5         5
#                 6        10
#                 7         2
#                 8         6
#                 9         5
#                 10       13
#                 11        1
#                 15        1
#                 16        1
# A Choudhary     16        1
#                 17        3
#                        ...
# Yuvraj Singh    2        15
# ...

# %%
batsman_per_over.groupby(['match_id','batsman','over'])['total_runs'].max()
# Out:
# match_id  batsman       over
# 1         A Choudhary   20       6
#           BCJ Cutting   19       1
#                         20      15
#           CH Gayle      1        1
#                         2        1
#                         3       11
#                         4       10
#                         5        5
#                         7        6
#           DA Warner     1        6
#                         2       11
#           DJ Hooda      16       2
#                         17       2
#                         18      10
#                         19       1
#                         20       1
#           KM Jadhav     7        0
#                         8        5
#                         9        9
#                         10       7
#                         11      11
#                         12       2
#           MC Henriques  2        4
#                         3        4
#                         4        2
#                         5        7
# ...

# %%
batsman_per_over.head()
# Out:
#    match_id      batsman  over  total_runs
# 0         1  A Choudhary    20           6
# 1         1  BCJ Cutting    19           1
# 2         1  BCJ Cutting    20          15
# 3         1     CH Gayle     1           1
# 4         1     CH Gayle     2           1

# %%
i = 1
for i in batsman_per_over.columns:
        print(batsman_per_over['over'][3])
# Out:
# 1
# 1
# 1
# 1

# %%
batsman_per_over.dtypes
# Out:
# match_id       int64
# batsman       object
# over           int64
# total_runs     int64
# dtype: object

# %%
batsman_per_over.batsman
# Out:
# 0         A Choudhary
# 1         BCJ Cutting
# 2         BCJ Cutting
# 3            CH Gayle
# 4            CH Gayle
# 5            CH Gayle
# 6            CH Gayle
# 7            CH Gayle
# 8            CH Gayle
# 9           DA Warner
# 10          DA Warner
# 11           DJ Hooda
# 12           DJ Hooda
# 13           DJ Hooda
# 14           DJ Hooda
# 15           DJ Hooda
# 16          KM Jadhav
# 17          KM Jadhav
# 18          KM Jadhav
# 19          KM Jadhav
# 20          KM Jadhav
# 21          KM Jadhav
# 22       MC Henriques
# 23       MC Henriques
# 24       MC Henriques
# 25       MC Henriques
# 26       MC Henriques
# 27       MC Henriques
# 28       MC Henriques
# 29       MC Henriques
#              ...
# 51483        S Dhawan
# 51484       SR Watson
# 51485       SR Watson
# 51486       SR Watson
# 51487       STR Binny
# 51488       STR Binny
# 51489       STR Binny
# 51490     Sachin Baby
# 51491     Sachin Baby
# 51492     Sachin Baby
# ...

# %%
batsman_per_over.groupby(['match_id','batsman','over'])['total_runs'].sum()
# Out:
# match_id  batsman       over
# 1         A Choudhary   20       6
#           BCJ Cutting   19       1
#                         20      15
#           CH Gayle      1        1
#                         2        1
#                         3       11
#                         4       10
#                         5        5
#                         7        6
#           DA Warner     1        6
#                         2       11
#           DJ Hooda      16       2
#                         17       2
#                         18      10
#                         19       1
#                         20       1
#           KM Jadhav     7        0
#                         8        5
#                         9        9
#                         10       7
#                         11      11
#                         12       2
#           MC Henriques  2        4
#                         3        4
#                         4        2
#                         5        7
# ...

# %%
c = batsman_per_over.groupby(batsman_per_over['over'])['total_runs'].sum()

# %%
c
# Out:
# over
# 1      7733
# 2      8993
# 3      9852
# 4     10207
# 5     10227
# 6     10397
# 7      8413
# 8      8966
# 9      9247
# 10     9047
# 11     9456
# 12     9694
# 13     9713
# 14     9900
# 15    10240
# 16    10397
# 17    10817
# 18    10899
# 19    10469
# 20     9647
# Name: total_runs, dtype: int64

# %%
dd = batsman_per_over.groupby(['over'])['total_runs'].sum()

# %%
dd['over']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-e47ad4a97b7d> in <module>
# ----> 1 dd['over']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# ...

# %%
bowl_eco.reset_index(inplace=True)

# %%
bowl_eco
# Out:
#       match_id           bowler  over  total_runs
# 0         7894         DJ Bravo    12          14
# 1         7894         DJ Bravo    16           4
# 2         7894         DJ Bravo    18           3
# 3         7894         DJ Bravo    20           6
# 4         7894        DL Chahar     1           5
# 5         7894        DL Chahar     3           5
# 6         7894        DL Chahar     5           4
# 7         7894        HH Pandya     4          12
# 8         7894        HH Pandya     6           3
# 9         7894        HH Pandya    10           6
# 10        7894        HH Pandya    17           6
# 11        7894  Harbhajan Singh     7           4
# 12        7894  Harbhajan Singh     9          10
# 13        7894      Imran Tahir    11          18
# 14        7894      Imran Tahir    15           5
# 15        7894        JJ Bumrah     3           3
# 16        7894        JJ Bumrah     8           6
# 17        7894        JJ Bumrah    16           9
# ...

# %%
bowl_eco.groupby(['match_id','bowler'])['total_runs'].sum()
# Out:
# match_id  bowler
# 1         A Choudhary          55
#           A Nehra              42
#           B Kumar              28
#           BCJ Cutting          35
#           Bipul Sharma          4
#           DJ Hooda              7
#           MC Henriques         20
#           Rashid Khan          36
#           S Aravind            36
#           SR Watson            41
#           STR Binny            10
#           TM Head              11
#           TS Mills             32
#           YS Chahal            22
# 2         A Zampa              27
#           AB Dinda             58
#           BA Stokes            36
#           DL Chahar            21
#           HH Pandya            37
#           Imran Tahir          28
#           JJ Bumrah            29
#           KA Pollard           30
#           KH Pandya            21
#           MJ McClenaghan       36
#           R Bhatia             14
#           TG Southee           34
# 3         CR Woakes            36
# ...

# %%
cc=bowl_eco.groupby(['match_id','bowler','over'])['total_runs'].sum(lambda x:(x==15).sum()).reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-111c2b1c0c7d> in <module>
# ----> 1 cc=bowl_eco.groupby(['match_id','bowler','over'])['total_runs'].sum(lambda x:(x==15).sum()).reset_index()
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
cc['over'>'15']
# Out:
# 4

# %%
cc.dtypes
# Out:
# dtype('int64')

# %%
temp_df = bowl_eco.groupby('bowler')['over'].agg(lambda x: (x>15).sum()).reset_index().sort_values(by='over', ascending=False).reset_index(drop=True)
#temp_df.to_csv('deathRuns1819.csv',index=False)

# %%
temp_df
# Out:
#                bowler  over
# 0            DJ Bravo   193
# 1          SL Malinga   193
# 2             B Kumar   157
# 3           SP Narine   134
# 4           JJ Bumrah   122
# 5            UT Yadav   117
# 6       R Vinay Kumar   113
# 7            DW Steyn   103
# 8              Z Khan   103
# 9             P Kumar   102
# 10          SR Watson    99
# 11           RP Singh    91
# 12          MM Sharma    90
# 13            A Nehra    88
# 14           L Balaji    87
# 15          IK Pathan    86
# 16           A Mishra    83
# 17         JD Unadkat    82
# 18          CH Morris    82
# 19          RA Jadeja    81
# 20        JP Faulkner    80
# 21           R Ashwin    74
# 22           AB Dinda    71
# 23          PP Chawla    70
# 24           M Morkel    65
# 25           I Sharma    64
# 26     MJ McClenaghan    62
# 27          JH Kallis    60
# 28        DS Kulkarni    56
# 29          JA Morkel    55
# ..                ...   ...
# 375        RR Bhatkal     0
# ...

# %%
temp_dfs = data.groupby('batsman')['total_runs'].agg(lambda x: (x==6).sum()).reset_index().sort_values(by='total_runs', ascending=False).reset_index(drop=True)
temp_dfs.to_csv('batsmans_six1617.csv',index=False)

# %%
temp_dfs
# Out:
#             batsman  total_runs
# 0         DA Warner          56
# 1    AB de Villiers          53
# 2           V Kohli          48
# 3        KA Pollard          39
# 4          CH Gayle          35
# 5        GJ Maxwell          34
# 6       BB McCullum          34
# 7           RR Pant          30
# 8          AJ Finch          30
# 9          MS Dhoni          30
# 10       RV Uthappa          29
# 11        SV Samson          27
# 12        RG Sharma          26
# 13       JC Buttler          26
# 14           N Rana          25
# 15         DR Smith          24
# 16         SK Raina          23
# 17        MK Pandey          21
# 18          HM Amla          21
# 19     Yuvraj Singh          21
# 20        HH Pandya          20
# 21          CA Lynn          20
# 22        SPD Smith          20
# 23        KH Pandya          20
# 24         AR Patel          19
# 25        YK Pathan          19
# 26        AM Rahane          18
# 27        CH Morris          18
# ...

# %%
temp_dfss = data.groupby('batsman')['total_runs'].agg(lambda x: (x==4).sum()).reset_index().sort_values(by='total_runs', ascending=False).reset_index(drop=True)
temp_dfss.to_csv('batsmans_four1819.csv',index=False)

# %%
temp_dfss
# Out:
#                batsman  total_runs
# 0             S Dhawan         125
# 1             KL Rahul         116
# 2             AS Yadav         106
# 3              RR Pant         104
# 4              V Kohli          98
# 5              CA Lynn          96
# 6             SK Raina          91
# 7           JC Buttler          91
# 8            SR Watson          86
# 9            AM Rahane          85
# 10           RG Sharma          77
# 11       KS Williamson          77
# 12            CH Gayle          77
# 13           AT Rayudu          75
# 14             SS Iyer          72
# 15          KD Karthik          72
# 16              P Shaw          72
# 17      AB de Villiers          70
# 18           Q de Kock          68
# 19            PA Patel          68
# 20           SV Samson          60
# 21           SP Narine          59
# 22           MK Pandey          58
# 23          RV Uthappa          58
# 24           DA Warner          58
# 25        F du Plessis          54
# ...

# %%
aa = bowl_eco.groupby('bowler')['over'].agg(lambda x: (x<7).sum()).reset_index().sort_values(by='over', ascending=False).reset_index(drop=True)
aa.to_csv('powerplay1819.csv',index=False)

# %%
aa
# Out:
#               bowler  over
# 0          DL Chahar    83
# 1            B Kumar    56
# 2           UT Yadav    52
# 3        DS Kulkarni    40
# 4          JJ Bumrah    38
# 5           TA Boult    38
# 6          K Gowtham    34
# 7     MJ McClenaghan    34
# 8           I Sharma    34
# 9          SP Narine    33
# 10   Harbhajan Singh    33
# 11         PP Chawla    32
# 12         SN Thakur    32
# 13          J Archer    31
# 14         P Krishna    31
# 15    Mohammed Shami    27
# 16         YS Chahal    26
# 17        AS Rajpoot    26
# 18    Sandeep Sharma    25
# 19           N Saini    23
# 20         KH Pandya    23
# 21        JD Unadkat    23
# 22        AD Russell    22
# 23        TG Southee    22
# 24         HH Pandya    21
# 25           K Ahmed    21
# 26            AJ Tye    21
# 27       M Ur Rahman    20
# 28            S Kaul    20
# 29        SL Malinga    19
# ..               ...   ...
# 103     DT Christian     1
# 104           J Dala     1
# ...

# %%
aaa = bowl_eco.groupby('bowler')['over'].agg('count')
aaa=pd.DataFrame(aaa)
aaa.reset_index(inplace=True)
aaa.sort_values(by='over',ascending=False)
wo = pd.merge(aaa,j,on='bowler',how='outer')
wo['WoPerOver'] = wo['wide_runs']/wo['over']
wo.head()
woo = pd.merge(wo,h,on='bowler',how='outer')
woo.head()
woo['NoPerOver'] = woo['noball_runs']/woo['over']
woo.head()
woo.rename(columns={'noball_runs':'noOFNoballs'})
woo.rename(columns={'wide_runs':'noOFWides'})
woo.to_csv('NOBALLWID1919.csv',index=False)

# %%
woo
# Out:
#                 bowler  over  wide_runs  WoPerOver  noball_runs  NoPerOver
# 0          A Dananjaya     4          1   0.250000            0   0.000000
# 1             A Joseph     9          3   0.333333            0   0.000000
# 2             A Mishra    77          7   0.090909            0   0.000000
# 3                A Roy     2          3   1.500000            0   0.000000
# 4              A Singh    10          5   0.500000            0   0.000000
# 5           AD Russell    69         12   0.173913            1   0.014493
# 6               AJ Tye    78         20   0.256410            2   0.025641
# 7             AR Patel    77          3   0.038961            0   0.000000
# 8           AS Rajpoot    43          8   0.186047            7   0.162791
# 9         Ankit Sharma     3          0   0.000000            1   0.333333
# 10       Anureet Singh     4          0   0.000000            0   0.000000
# ...

# %%
aaa.head()
# Out:
#            bowler  over
# 0  A Ashish Reddy    45
# 1      A Chandila    39
# 2     A Choudhary    17
# 3     A Dananjaya     4
# 4      A Flintoff    11

# %%
aa
# Out:
#               bowler  over
# 0            P Kumar   262
# 1            B Kumar   231
# 2             Z Khan   217
# 3           I Sharma   201
# 4         SL Malinga   185
# 5           DW Steyn   183
# 6            A Nehra   183
# 7           UT Yadav   176
# 8           RP Singh   167
# 9        DS Kulkarni   166
# 10    Sandeep Sharma   157
# 11         IK Pathan   153
# 12          M Morkel   151
# 13         JA Morkel   150
# 14         SR Watson   139
# 15          R Ashwin   136
# 16          AB Dinda   135
# 17         MM Sharma   131
# 18     R Vinay Kumar   126
# 19   Harbhajan Singh   124
# 20         SP Narine   116
# 21    MJ McClenaghan   109
# 22          MM Patel   109
# 23        MG Johnson   104
# 24         JJ Bumrah    95
# 25       S Sreesanth    95
# 26         DL Chahar    94
# 27        JD Unadkat    87
# 28         JH Kallis    86
# 29         CH Morris    84
# ..               ...   ...
# 375        BJ Rohrer     0
# 376         S Vidyut     0
# ...

# %%
a = data.groupby('batsman')[''].agg('sum').reset_index().sort_values(by='batsman_runs',ascending=False)
a.to_csv('batsmans.csv',index=False)

# %%
data1 = pd.read_csv('datasets/mm.csv')

# %%
data1.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# #

# %%
data1=data1[data1.season != '2017']

# %%
data1.to_csv('final.csv',index=False)

# %%
data1.head()
# Out:
# Empty DataFrame
# Columns: [id, season, city, date, team1, team2, toss_winner, toss_decision, result, dl_applied, winner, win_by_runs, win_by_wickets, player_of_match, venue, umpire1, umpire2, umpire3]
# Index: []

# %%
data = pd.read_csv('datasets/matches.csv')
data22 = pd.read_csv('datasets/1617.csv')
data1 = pd.read_excel('bowler/BowlerOuter.xlsx',sheet_name='1617')

# %%
data22.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  noball_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...            0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...            0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...            0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...            0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...            0
#
# ...

# %%
data1.head()
# Out:
#            bowler  total_overs  total_runs  avg_economy  death_over  over  \
# 0  A Ashish Reddy           45         400     8.888889          18    45
# 1      A Chandila           39         245     6.282051           1    39
# 2     A Choudhary           17         144     8.470588           4    17
# 3     A Dananjaya            4          48    12.000000           0     4
# 4      A Flintoff           11         106     9.636364           4    11
#
#    wide_runs  WoPerOver  noball_runs  NoPerOver  powerplay_over  wickets
# 0          8   0.177778            2   0.044444               1      1.0
# 1          0   0.000000            0   0.000000              24      NaN
# 2          6   0.352941            1   0.058824               6      5.0
# 3          1   0.250000            0   0.000000               1      NaN
# 4          0   0.000000            0   0.000000               2      NaN

# %%
a = data22.groupby(['player_of_match','match_id'])['match_id'].agg('count')
a.head()
#a = pd.DataFrame(a)
#a = a.reset_index()
#a= a.rename(columns={'player_of_match':'bowler'})
#a.head()
#a.sort_values(by='match_id',ascending=False)
#b = pd.merge(a,data1,on='bowler',how = 'outer')
#b= b.rename(columns={'match_id':'MOM'})
#b.to_csv('MOM1617.csv',index=False)
# Out:
# player_of_match  match_id
# A Mishra         583         207
# A Nehra          613         226
# A Zampa          616         244
# AB Dinda         598         196
#                  625         193
# Name: match_id, dtype: int64

# %%
b.head()
# Out:
#            bowler    MOM  total_overs  total_runs  avg_economy  death_over  \
# 0        A Mishra  207.0        519.0      3850.0     7.418112        83.0
# 1         A Nehra  226.0        320.0      2537.0     7.928125        88.0
# 2         A Zampa  244.0         37.0       281.0     7.594595         8.0
# 3        AB Dinda  389.0        255.0      2103.0     8.247059        71.0
# 4  AB de Villiers  986.0          NaN         NaN          NaN         NaN
#
#     over  wide_runs  WoPerOver  noball_runs  NoPerOver  powerplay_over  \
# 0  519.0       57.0   0.109827         20.0   0.038536            22.0
# 1  320.0       64.0   0.200000          9.0   0.028125           183.0
# 2   37.0        8.0   0.216216          0.0   0.000000             1.0
# 3  255.0       72.0   0.282353         14.0   0.054902           135.0
# 4    NaN        NaN        NaN          NaN        NaN             NaN
#
#    wickets
# 0     24.0
# 1     21.0
# 2     19.0
# 3     15.0
# 4      NaN

# %%
b.to_csv('MOM.csv',index=False)

# %%
c = data22.groupby('bowler')['player_dismissed'].agg('count').reset_index().sort_values(by='player_dismissed',ascending=False)

# %%
c
# Out:
#               bowler  player_dismissed
# 340       SL Malinga               188
# 93          DJ Bravo               168
# 7           A Mishra               165
# 126  Harbhajan Singh               161
# 264        PP Chawla               156
# 53           B Kumar               141
# 269         R Ashwin               138
# 347        SP Narine               137
# 381         UT Yadav               136
# 281    R Vinay Kumar               127
# 9            A Nehra               121
# 404           Z Khan               119
# 282        RA Jadeja               116
# 350        SR Watson               107
# 108         DW Steyn               104
# 402        YS Chahal               102
# 251          P Kumar               102
# 292         RP Singh               100
# 265          PP Ojha                99
# 226        MM Sharma                99
# 133        IK Pathan                99
# 145        JA Morkel                96
# 153        JJ Bumrah                91
# ...

# %%
c = data22.groupby('bowler')['player_dismissed'].agg('count').reset_index().sort_values(by='player_dismissed',ascending=False)

# %%
c.head()
# Out:
#              bowler  player_dismissed
# 16          B Kumar                52
# 53        JJ Bumrah                41
# 74   MJ McClenaghan                38
# 140       YS Chahal                36
# 125  Sandeep Sharma                36

# %%
data = pd.read_csv('datasets/matches.csv')

# %%
a1 = data.season>=2018
a2=data[a1]
a3=a2.season<=2019
a4=a2[a3]
a5=a4.groupby(['player_of_match'])['id'].agg('count')
a5=a5.reset_index()
a5.to_csv('1819mom.csv',index=False)

# %%
d=pd.read_excel('bowler\BowlerOuter.xlsx')
d1=pd.read_excel('batsman/batsmanOuter.xlsx')
d2=pd.read_csv('1617mom.csv')
d3=pd.read_csv('1819mom.csv')
